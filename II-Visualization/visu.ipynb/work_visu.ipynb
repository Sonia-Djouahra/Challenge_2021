# %%
import pandas as pd
import json
import urllib, json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import path
from download import download
from pandas import json_normalize
from ipywidgets import interact
import datetime
from pandas import Series

# %%
url = [
    "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H19070220_archive.json",#Berracasa
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20042632_archive.json",#Laverure
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20042633_archive.json",#Celleneuve
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20042634_archive.json",#Lattes2
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20042635_archive.json",#Lattes1
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20063161_archive.json",#Vieille poste
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20063162_archive.json",#Gerhardt
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_XTH19101158_archive.json",#Albert1er
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20063163_archive.json",#Delmas1
   "https://data.montpellier3m.fr/sites/default/files/ressources/MMM_EcoCompt_X2H20063164_archive.json"#Delmas2
]
#Berracasa
path_target_Ber = "Berracasa.json"
download(url[0],path_target_ber, replace = False)
data_Ber = pd.read_json('berracasa.json', lines= True)
data_Ber.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Laverune
path_target_Lav= "Laverune.json"
download(url[1],path_target_Lav, replace=False)
data_Lav = pd.read_json('Laverune.json', lines= True)
data_Lav.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Celleneuve
path_target_Cel= "Celleneuve.json"
download(url[2],path_target_Cel, replace=False)
data_Cel = pd.read_json('Celleneuve.json', lines= True)
data_Cel.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Lattes1
path_target_Lat1= "Lattes1.json"
download(url[3],path_target_Lat1, replace=False)
data_Lat1 = pd.read_json('Lattes1.json', lines= True)
data_Lat1.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Lattes2
path_target_Lat2= "Lattes2.json"
download(url[4],path_target_Lat2, replace=False)
data_Lat2 = pd.read_json('Lattes2.json', lines= True)
data_Lat2.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Vieille Poste
path_target_ViePo= "VieillePo.json"
download(url[5],path_target_ViePo, replace=False)
data_ViePo = pd.read_json('VieillePo.json', lines= True)
data_ViePo.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Gerhardt
path_target_Ger= "Gerhardt.json"
download(url[6],path_target_Ger, replace=False)
data_Ger = pd.read_json('Gerhardt.json', lines= True)
data_Ger.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Albert 1
path_target_Alb= "Albert.json"
download(url[7],path_target_Alb, replace=False)
data_Alb = pd.read_json('Albert.json', lines= True)
data_Alb.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Delmas1
path_target_Del1= "Delmas1.json"
download(url[8],path_target_Del1, replace=False)
data_Del1 = pd.read_json('Delmas1.json', lines= True)
data_Del1.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
#Delmas2
path_target_Del2= "Delmas2.json"
download(url[9],path_target_Del2, replace=False)
data_Del2 = pd.read_json('Delmas2.json', lines= True)
data_Del2.columns = ['Intensity','LaneID', 'DateObserved', 'Location', 'ID', 'Type', 'VehiculeType', 'ReverseLane']
# Out:
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.
# Replace is False and data exists, so doing nothing. Use replace=True to re-download the data.

# %%
#Séparation jours par jours
data_test=data_Alb.join(data_Alb['DateObserved'].apply(lambda x: Series(x.split('/'))))
data_test=data_test.rename(columns = {0: 'start_of_day', 1: 'end_of_day'}) 
data_test['start_of_day'] = data_test['start_of_day'].str.replace('T',' ')
time_improved = pd.to_datetime(data_test['start_of_day'] ,format='%Y-%m-%d %H:%M:%S')
#debut fin journée
data_test['start_day'] = time_improved
data_test = data_test.set_index(['start_day'])

# %%
Lattes1 = data_Lat1['Intensity']
Lattes2 = data_Lat2['Intensity']
Albert1 = data_Alb['Intensity']
Celleneuve = data_Cel['Intensity']
Laverune = data_Lav['Intensity']
Delmas1 = data_Del1['Intensity']
Delmas2 = data_Del2['Intensity']
Gerhardt= data_Ger['Intensity']
VieillePoste= data_ViePo['Intensity']
Berracassa = data_Ber['Intensity']

# %%
data = pd.DataFrame(columns=['Day','Albert1','Berracassa', 'Celleneuve','Delmas1','Delmas2', 'Gerhardt','Lattes1','Lattes2','Laverune','VieillePoste'])
data.Lattes1 = Lattes1 
data.Lattes2 = Lattes2
data.Berracassa = Berracassa
data.Celleneuve = Celleneuve
data.Laverune = Laverune
data.Delmas1 = Delmas1
data.Delmas2 = Delmas2
data.VieillePoste = VieillePoste
data.Day = time_improved
data.Gerhardt = Gerhardt
data.Albert1 = Albert1
#Suppression des NAN
index_with_nan = data.index[data.isnull().any(axis=1)]
data.drop(index_with_nan,0, inplace=True)

# %%
#Construction Diagramme ALBERT1
Dia_Alb =  pd.DataFrame(columns=['Day','Albert1'])
Dia_Alb.Day = time_improved
Dia_Alb.Albert1 = Albert1

# Mois décembre
Dia_Alb_12 = Dia_Alb[(Dia_Alb.Day > '2020-12-01') & (Dia_Alb.Day < '2020-12-31')]
Moyenne_Alb_12 = Dia_Alb_12['Albert1'].mean()
Moyenne_Alb_12 = Moyenne_Alb_12
# Mois JANVIER
Dia_Alb_01 = Dia_Alb[(Dia_Alb.Day > '2021-01-01') & (Dia_Alb.Day < '2021-01-31')]
Moyenne_Alb_01 = Dia_Alb_01['Albert1'].mean()
Moyenne_Alb_01 = Moyenne_Alb_01
# Mois FEVRIER
Dia_Alb_02 = Dia_Alb[(Dia_Alb.Day > '2021-02-01')& (Dia_Alb.Day < '2021-02-28')]
Moyenne_Alb_02 = Dia_Alb_02['Albert1'].mean()
Moyenne_Alb_02 = Moyenne_Alb_02
#Mois MARS
Dia_Alb_03 = Dia_Alb[(Dia_Alb.Day > '2021-03-01')& (Dia_Alb.Day < '2021-03-31')]
Moyenne_Alb_03 = Dia_Alb_03['Albert1'].mean()
Moyenne_Alb_03 = Moyenne_Alb_03
# DIAGRAMME ALBERT1
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

albert1 = [Moyenne_Alb_12, Moyenne_Alb_01, Moyenne_Alb_02, Moyenne_Alb_03, ]
plt.title("Intensity Albert 1")

plt.bar(Mois, albert1, color='red')

plt.show()

# %%
#Construction Diagramme Berracassa
Dia_Ber =  pd.DataFrame(columns=['Day','Berracassa'])
Dia_Ber.Day = time_improved
Dia_Ber.Berracassa = Berracassa

# Mois décembre
Dia_Ber_12 = Dia_Ber[(Dia_Ber.Day > '2020-12-01') & (Dia_Ber.Day < '2020-12-31')]
Moyenne_Ber_12 = Dia_Ber_12['Berracassa'].mean()
Moyenne_Ber_12 = int(Moyenne_Ber_12)
# Mois JANVIER
Dia_Ber_01 = Dia_Ber[(Dia_Ber.Day > '2021-01-01') & (Dia_Ber.Day < '2021-01-31')]
Moyenne_Ber_01 = Dia_Ber_01['Berracassa'].mean()
Moyenne_Ber_01 = int(Moyenne_Ber_01)
# Mois FEVRIER
Dia_Ber_02 = Dia_Ber[(Dia_Ber.Day > '2021-02-01')& (Dia_Ber.Day < '2021-02-28')]
Moyenne_Ber_02 = Dia_Ber_02['Berracassa'].mean()
Moyenne_Ber_02 = int(Moyenne_Ber_02)
#Mois MARS
Dia_Ber_03 = Dia_Ber[(Dia_Ber.Day > '2021-03-01')& (Dia_Ber.Day < '2021-03-31')]
Moyenne_Ber_03 = Dia_Ber_03['Berracassa'].mean()
Moyenne_Ber_03 = int(Moyenne_Ber_03)
# DIAGRAMME ALBERT1
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

berracassa = [Moyenne_Ber_12, Moyenne_Ber_01, Moyenne_Ber_02, Moyenne_Ber_03 ]
plt.title("Intensity Berracassa")

plt.bar(Mois,berracassa,color='tab:blue' )

plt.show()

# %%
#Construction Diagramme Laverune
Dia_Lav =  pd.DataFrame(columns=['Day','Laverune'])
Dia_Lav.Day = time_improved
Dia_Lav.Laverune = Laverune

# Mois décembre
Dia_Lav_12 = Dia_Lav[(Dia_Lav.Day > '2020-12-01') & (Dia_Lav.Day < '2020-12-31')]
Moyenne_Lav_12 = Dia_Lav_12['Laverune'].mean()
Moyenne_Lav_12 = int(Moyenne_Lav_12)
# Mois JANVIER
Dia_Lav_01 = Dia_Lav[(Dia_Lav.Day > '2021-01-01') & (Dia_Lav.Day < '2021-01-31')]
Moyenne_Lav_01 = Dia_Lav_01['Laverune'].mean()
Moyenne_Lav_01 = int(Moyenne_Lav_01)
# Mois FEVRIER
Dia_Lav_02 = Dia_Lav[(Dia_Lav.Day > '2021-02-01')& (Dia_Lav.Day < '2021-02-28')]
Moyenne_Lav_02 = Dia_Lav_02['Laverune'].mean()
Moyenne_Lav_02 = int(Moyenne_Lav_02)
#Mois MARS
Dia_Lav_03 = Dia_Lav[(Dia_Lav.Day > '2021-03-01')& (Dia_Lav.Day < '2021-03-31')]
Moyenne_Lav_03 = Dia_Lav_03['Laverune'].mean()
Moyenne_Lav_03 = int(Moyenne_Lav_03)
# DIAGRAMME ALBERT1
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

laverune = [Moyenne_Lav_12, Moyenne_Lav_01, Moyenne_Lav_02, Moyenne_Lav_03 ]
plt.title("Intensity Laverune")

plt.bar(Mois,laverune, color='tab:pink' )

plt.show()
Dia_Lav.Day = time_improved

# %%
#Construction Diagramme Lat1erune
Dia_Lat1 =  pd.DataFrame(columns=['Day','Lattes1'])
Dia_Lat1.Day = time_improved
Dia_Lat1.Lattes1 = Lattes1

# Mois décembre
Dia_Lat1_12 = Dia_Lat1[(Dia_Lat1.Day > '2020-12-01') & (Dia_Lat1.Day < '2020-12-31')]
Moyenne_Lat1_12 = Dia_Lat1_12['Lattes1'].mean()
Moyenne_Lat1_12 = int(Moyenne_Lat1_12)
# Mois JANVIER
Dia_Lat1_01 = Dia_Lat1[(Dia_Lat1.Day > '2021-01-01') & (Dia_Lat1.Day < '2021-01-31')]
Moyenne_Lat1_01 = Dia_Lat1_01['Lattes1'].mean()
Moyenne_Lat1_01 = int(Moyenne_Lat1_01)
# Mois FEVRIER
Dia_Lat1_02 = Dia_Lat1[(Dia_Lat1.Day > '2021-02-01')& (Dia_Lat1.Day < '2021-02-28')]
Moyenne_Lat1_02 = Dia_Lat1_02['Lattes1'].mean()
Moyenne_Lat1_02 = int(Moyenne_Lat1_02)
#Mois MARS
Dia_Lat1_03 = Dia_Lat1[(Dia_Lat1.Day > '2021-03-01')& (Dia_Lat1.Day < '2021-03-31')]
Moyenne_Lat1_03 = Dia_Lat1_03['Lattes1'].mean()
Moyenne_Lat1_03 = int(Moyenne_Lat1_03)
# DIAGRAMME ALBERT1
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

lattes1 = [Moyenne_Lat1_12, Moyenne_Lat1_01, Moyenne_Lat1_02, Moyenne_Lat1_03 ]
plt.title("Intensity Lattes1")

plt.bar(Mois,lattes1, color='tab:olive' )

plt.show()

# %%
#Construction Diagramme Lat2erune
Dia_Lat2 =  pd.DataFrame(columns=['Day','Lattes2'])
Dia_Lat2.Day = time_improved
Dia_Lat2.Lattes2 = Lattes2

# Mois décembre
Dia_Lat2_12 = Dia_Lat2[(Dia_Lat2.Day > '2020-12-01') & (Dia_Lat2.Day < '2020-12-31')]
Moyenne_Lat2_12 = Dia_Lat2_12['Lattes2'].mean()
Moyenne_Lat2_12 = int(Moyenne_Lat2_12)
# Mois JANVIER
Dia_Lat2_01 = Dia_Lat2[(Dia_Lat2.Day > '2021-01-01') & (Dia_Lat2.Day < '2021-01-31')]
Moyenne_Lat2_01 = Dia_Lat2_01['Lattes2'].mean()
Moyenne_Lat2_01 = int(Moyenne_Lat2_01)
# Mois FEVRIER
Dia_Lat2_02 = Dia_Lat2[(Dia_Lat2.Day > '2021-02-01')& (Dia_Lat2.Day < '2021-02-28')]
Moyenne_Lat2_02 = Dia_Lat2_02['Lattes2'].mean()
Moyenne_Lat2_02 = int(Moyenne_Lat2_02)
#Mois MARS
Dia_Lat2_03 = Dia_Lat2[(Dia_Lat2.Day > '2021-03-01')& (Dia_Lat2.Day < '2021-03-31')]
Moyenne_Lat2_03 = Dia_Lat2_03['Lattes2'].mean()
Moyenne_Lat2_03 = int(Moyenne_Lat2_03)
# DIAGRAMME ALBERt2
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

lattes2 = [Moyenne_Lat2_12, Moyenne_Lat2_01, Moyenne_Lat2_02, Moyenne_Lat2_03 ]
plt.title("Intensity Lattes2")

plt.bar(Mois,lattes2, color='tab:orange' )

plt.show()

# %%
#Construction Diagramme Del1erune
Dia_Del1 =  pd.DataFrame(columns=['Day','Delmas1'])
Dia_Del1.Day = time_improved
Dia_Del1.Delmas1 = Delmas1

# Mois décembre
Dia_Del1_12 = Dia_Del1[(Dia_Del1.Day > '2020-12-01') & (Dia_Del1.Day < '2020-12-31')]
Moyenne_Del1_12 = Dia_Del1_12['Delmas1'].mean()
Moyenne_Del1_12 = int(Moyenne_Del1_12)
# Mois JANVIER
Dia_Del1_01 = Dia_Del1[(Dia_Del1.Day > '2021-01-01') & (Dia_Del1.Day < '2021-01-31')]
Moyenne_Del1_01 = Dia_Del1_01['Delmas1'].mean()
Moyenne_Del1_01 = int(Moyenne_Del1_01)
# Mois FEVRIER
Dia_Del1_02 = Dia_Del1[(Dia_Del1.Day > '2021-02-01')& (Dia_Del1.Day < '2021-02-28')]
Moyenne_Del1_02 = Dia_Del1_02['Delmas1'].mean()
Moyenne_Del1_02 = int(Moyenne_Del1_02)
#Mois MARS
Dia_Del1_03 = Dia_Del1[(Dia_Del1.Day > '2021-03-01')& (Dia_Del1.Day < '2021-03-31')]
Moyenne_Del1_03 = Dia_Del1_03['Delmas1'].mean()
Moyenne_Del1_03 = int(Moyenne_Del1_03)
# DIAGRAMME ALBERt2
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

delmas1 = [Moyenne_Del1_12, Moyenne_Del1_01, Moyenne_Del1_02, Moyenne_Del1_03 ]
plt.title("Intensity Delmas1")

plt.bar(Mois,delmas1, color ='tab:brown' )

plt.show()

# %%
#Construction Diagramme Del2erune
Dia_Del2 =  pd.DataFrame(columns=['Day','Delmas2'])
Dia_Del2.Day = time_improved
Dia_Del2.Delmas2 = Delmas2

# Mois décembre
Dia_Del2_12 = Dia_Del2[(Dia_Del2.Day > '2020-12-01') & (Dia_Del2.Day < '2020-12-31')]
Moyenne_Del2_12 = Dia_Del2_12['Delmas2'].mean()
Moyenne_Del2_12 = int(Moyenne_Del2_12)
# Mois JANVIER
Dia_Del2_01 = Dia_Del2[(Dia_Del2.Day > '2021-01-01') & (Dia_Del2.Day < '2021-01-31')]
Moyenne_Del2_01 = Dia_Del2_01['Delmas2'].mean()
Moyenne_Del2_01 = int(Moyenne_Del2_01)
# Mois FEVRIER
Dia_Del2_02 = Dia_Del2[(Dia_Del2.Day > '2021-02-01')& (Dia_Del2.Day < '2021-02-28')]
Moyenne_Del2_02 = Dia_Del2_02['Delmas2'].mean()
Moyenne_Del2_02 = int(Moyenne_Del2_02)
#Mois MARS
Dia_Del2_03 = Dia_Del2[(Dia_Del2.Day > '2021-03-01')& (Dia_Del2.Day < '2021-03-31')]
Moyenne_Del2_03 = Dia_Del2_03['Delmas2'].mean()
Moyenne_Del2_03 = int(Moyenne_Del2_03)
# DIAGRAMME ALBERt2
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

delmas2 = [Moyenne_Del2_12, Moyenne_Del2_01, Moyenne_Del2_02, Moyenne_Del2_03 ]
plt.title("Intensity Delmas2")

plt.bar(Mois,delmas2,color='black' )

plt.show()

# %%
#Construction Diagramme Celerune
Dia_Cel =  pd.DataFrame(columns=['Day','Celleneuve'])
Dia_Cel.Day = time_improved
Dia_Cel.Celleneuve = Celleneuve

# Mois décembre
Dia_Cel_12 = Dia_Cel[(Dia_Cel.Day > '2020-12-01') & (Dia_Cel.Day < '2020-12-31')]
Moyenne_Cel_12 = Dia_Cel_12['Celleneuve'].mean()
Moyenne_Cel_12 = int(Moyenne_Cel_12)
# Mois JANVIER
Dia_Cel_01 = Dia_Cel[(Dia_Cel.Day > '2021-01-01') & (Dia_Cel.Day < '2021-01-31')]
Moyenne_Cel_01 = Dia_Cel_01['Celleneuve'].mean()
Moyenne_Cel_01 = int(Moyenne_Cel_01)
# Mois FEVRIER
Dia_Cel_02 = Dia_Cel[(Dia_Cel.Day > '2021-02-01')& (Dia_Cel.Day < '2021-02-28')]
Moyenne_Cel_02 = Dia_Cel_02['Celleneuve'].mean()
Moyenne_Cel_02 = int(Moyenne_Cel_02)
#Mois MARS
Dia_Cel_03 = Dia_Cel[(Dia_Cel.Day > '2021-03-01')& (Dia_Cel.Day < '2021-03-31')]
Moyenne_Cel_03 = Dia_Cel_03['Celleneuve'].mean()
Moyenne_Cel_03 = int(Moyenne_Cel_03)
# DIAGRAMME ALBERt2
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

celleneuve = [Moyenne_Cel_12, Moyenne_Cel_01, Moyenne_Cel_02, Moyenne_Cel_03 ]
plt.title("Intensity Celleneuve")

plt.bar(Mois,celleneuve, color='tab:gray')

plt.show()

# %%
#Construction Diagramme Gererune
Dia_Ger =  pd.DataFrame(columns=['Day','Gerhardt'])
Dia_Ger.Day = time_improved
Dia_Ger.Gerhardt = Gerhardt

# Mois décembre
Dia_Ger_12 = Dia_Ger[(Dia_Ger.Day > '2020-12-01') & (Dia_Ger.Day < '2020-12-31')]
Moyenne_Ger_12 = Dia_Ger_12['Gerhardt'].mean()
Moyenne_Ger_12 = int(Moyenne_Ger_12)
# Mois JANVIER
Dia_Ger_01 = Dia_Ger[(Dia_Ger.Day > '2021-01-01') & (Dia_Ger.Day < '2021-01-31')]
Moyenne_Ger_01 = Dia_Ger_01['Gerhardt'].mean()
Moyenne_Ger_01 = int(Moyenne_Ger_01)
# Mois FEVRIER
Dia_Ger_02 = Dia_Ger[(Dia_Ger.Day > '2021-02-01')& (Dia_Ger.Day < '2021-02-28')]
Moyenne_Ger_02 = Dia_Ger_02['Gerhardt'].mean()
Moyenne_Ger_02 = int(Moyenne_Ger_02)
#Mois MARS
Dia_Ger_03 = Dia_Ger[(Dia_Ger.Day > '2021-03-01')& (Dia_Ger.Day < '2021-03-31')]
Moyenne_Ger_03 = Dia_Ger_03['Gerhardt'].mean()
Moyenne_Ger_03 = int(Moyenne_Ger_03)
# DIAGRAMME ALBERt2
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

gerhardt = [Moyenne_Ger_12, Moyenne_Ger_01, Moyenne_Ger_02, Moyenne_Ger_03 ]
plt.title("Intensity Gerhardt")

plt.bar(Mois,gerhardt, color='c' )

plt.show()

# %%
#Construction Diagramme ViePoerune
Dia_ViePo =  pd.DataFrame(columns=['Day','VieillePoste'])
Dia_ViePo.Day = time_improved
Dia_ViePo.VieillePoste = VieillePoste

# Mois décembre
Dia_ViePo_12 = Dia_ViePo[(Dia_ViePo.Day > '2020-12-01') & (Dia_ViePo.Day < '2020-12-31')]
Moyenne_ViePo_12 = Dia_ViePo_12['VieillePoste'].mean()
Moyenne_ViePo_12 = int(Moyenne_ViePo_12)
# Mois JANVIER
Dia_ViePo_01 = Dia_ViePo[(Dia_ViePo.Day > '2021-01-01') & (Dia_ViePo.Day < '2021-01-31')]
Moyenne_ViePo_01 = Dia_ViePo_01['VieillePoste'].mean()
Moyenne_ViePo_01 = int(Moyenne_ViePo_01)
# Mois FEVRIER
Dia_ViePo_02 = Dia_ViePo[(Dia_ViePo.Day > '2021-02-01')& (Dia_ViePo.Day < '2021-02-28')]
Moyenne_ViePo_02 = Dia_ViePo_02['VieillePoste'].mean()
Moyenne_ViePo_02 = int(Moyenne_ViePo_02)
#Mois MARS
Dia_ViePo_03 = Dia_ViePo[(Dia_ViePo.Day > '2021-03-01')& (Dia_ViePo.Day < '2021-03-31')]
Moyenne_ViePo_03 = Dia_ViePo_03['VieillePoste'].mean()
Moyenne_ViePo_03 = int(Moyenne_ViePo_03)
# DIAGRAMME ALBERt2
Mois = ['Décembre', 'Janvier', 'Fevrier', 'Mars']

vieillePoste = [Moyenne_ViePo_12, Moyenne_ViePo_01, Moyenne_ViePo_02, Moyenne_ViePo_03 ]
plt.title("Intensity VieillePoste")

plt.bar(Mois,vieillePoste, color='tab:purple' )

plt.show()

# %%
#Diagramme emboité
vieillePoste = [Moyenne_ViePo_12, Moyenne_ViePo_01, Moyenne_ViePo_02, Moyenne_ViePo_03 ]
gerhardt = [Moyenne_Ger_12, Moyenne_Ger_01, Moyenne_Ger_02, Moyenne_Ger_03 ]
delmas2 = [Moyenne_Del2_12, Moyenne_Del2_01, Moyenne_Del2_02, Moyenne_Del2_03 ]
celleneuve = [Moyenne_Cel_12, Moyenne_Cel_01, Moyenne_Cel_02, Moyenne_Cel_03 ]
delmas1 = [Moyenne_Del1_12, Moyenne_Del1_01, Moyenne_Del1_02, Moyenne_Del1_03 ]
lattes2 = [Moyenne_Lat2_12, Moyenne_Lat2_01, Moyenne_Lat2_02, Moyenne_Lat2_03 ]
lattes1 = [Moyenne_Lat1_12, Moyenne_Lat1_01, Moyenne_Lat1_02, Moyenne_Lat1_03 ]
berracassa = [Moyenne_Ber_12, Moyenne_Ber_01, Moyenne_Ber_02, Moyenne_Ber_03 ]
laverune = [Moyenne_Lav_12, Moyenne_Lav_01, Moyenne_Lav_02, Moyenne_Lav_03 ]
albert1 = [Moyenne_Alb_12, Moyenne_Alb_01, Moyenne_Alb_02, Moyenne_Alb_03, ]

month=["December","Junuary","February","March"]

plt.figure(figsize=(9,7))
plt.bar(month,vieillePoste,color="tab:purple",label="VieillePoste")
plt.bar(month,gerhardt,color="c",bottom=np.array(vieillePoste),label="Gerhardt")
plt.bar(month,delmas1,color="tab:brown",bottom=np.array(vieillePoste)+np.array(gerhardt),label="Delmas1")
plt.bar(month,delmas2,color="black",bottom=np.array(vieillePoste)+np.array(gerhardt)+np.array(delmas1),label="Delmas2")
plt.bar(month,celleneuve,color="tab:gray",bottom=np.array(vieillePoste)+np.array(gerhardt)+np.array(delmas1)+np.array(delmas2),label="Celleneuve")
plt.bar(month,lattes1,color="tab:olive",bottom=np.array(vieillePoste)+np.array(gerhardt)+np.array(delmas1)+np.array(delmas2)+np.array(celleneuve),label="Lattes1")
plt.bar(month,lattes2,color="tab:orange",bottom=np.array(vieillePoste)+np.array(gerhardt)+np.array(delmas1)+np.array(delmas2)+np.array(celleneuve)+np.array(lattes1),label="Lattes2")

plt.bar(month,laverune,color="tab:pink",bottom=np.array(vieillePoste)+np.array(gerhardt)+np.array(delmas1)+np.array(delmas2)+np.array(celleneuve)+np.array(lattes1)+np.array(lattes2),label="Laverune")
plt.bar(month,berracassa,color="tab:blue",bottom=np.array(vieillePoste)+np.array(gerhardt)+np.array(delmas1)+np.array(delmas2)+np.array(celleneuve)+np.array(lattes1)+np.array(lattes2)+np.array(laverune),label="Berracassa")

plt.bar(month,albert1,color="red",bottom=np.array(vieillePoste)+np.array(gerhardt)+np.array(delmas1)+np.array(delmas2)+np.array(celleneuve)+np.array(lattes1)+np.array(lattes2)+np.array(laverune)+np.array(berracassa),label="Albert1")

plt.suptitle('Global intensity')


plt.legend(loc="lower left",bbox_to_anchor=(0.8,1.0))
plt.show()

# %%
# Variable camenbert
mean_Alb = int(data_Alb['Intensity'].mean())
mean_Ber = int(data_Ber['Intensity'].mean())
mean_Cel = int(data_Cel['Intensity'].mean())
mean_Lav = int(data_Lav['Intensity'].mean())
mean_Lat1 = int(data_Lat1['Intensity'].mean())
mean_Lat2 = int(data_Lat2['Intensity'].mean())
mean_ViePo = int(data_ViePo['Intensity'].mean())
mean_Ger = int(data_Ger['Intensity'].mean())
mean_Del1 = int(data_Del1['Intensity'].mean())
mean_Del2 = int(data_Del2['Intensity'].mean())

# %%
#Camembert de la moyenne des stations (sur les 3 mois)
labels = ['Albert 1','Berracassa','Celleneuve','Delmas 1', 'Delmas 2', 'Gerhardt', 'Lattes 1', 'Lattes 2', 'Laverune', 'Vieille Poste' ]
sizes =[mean_Alb,mean_Ber,mean_Cel,mean_Del1,mean_Del2,mean_Ger,mean_Lat1,mean_Lat2,mean_Lav,mean_ViePo]
colors = ['tab:orange','tab:olive','tab:gray','tab:pink','tab:brown','c','tab:green','r','tab:purple','tab:blue' ]
#air = [] #explode=air
plt.pie(sizes,  labels=labels, colors=colors, 
        autopct='%1.1f%%', shadow=True, startangle=200)
#plt.axis('equal')

plt.suptitle('Average intensity over three months')

plt.show()
